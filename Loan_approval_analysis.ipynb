# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv("loan_dataset.csv")
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
df = df.drop("Loan_ID", axis=1)

# %%
df.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
X = df.drop("Loan_Status", axis=1)
y = df["Loan_Status"]

# %%
X = pd.get_dummies(X, drop_first=True)
cat_cols = X.select_dtypes(include="object").columns
for col in cat_cols:
    X[col] = X[col].fillna(X[col].mode()[0])
num_cols = X.select_dtypes(exclude="object").columns
for col in num_cols:
    X[col] = X[col].fillna(X[col].median())

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X[num_cols] = scaler.fit_transform(X[num_cols])

# %%
gender_series = df["Gender"].copy()

# %%
X_train, X_test, y_train, y_test, gender_train, gender_test = train_test_split(X, y, gender_series, test_size=0.2, random_state=42)

# %%
model = LogisticRegression(max_iter=1000)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
print(y_pred[:10])
# Out:
# ['Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y']

# %%
y_pred.shape
# Out:
# (123,)

# %%
y_test.shape
# Out:
# (123,)

# %%
pd.Series(y_pred).value_counts()
# Out:
# Y    104
# N     19
# Name: count, dtype: int64

# %%
results = pd.DataFrame({
    "true": y_test.values,
    "pred": y_pred,
    "gender": gender_test.values
})

# %%
results.head()
# Out:
#   true pred  gender
# 0    Y    Y    Male
# 1    Y    Y    Male
# 2    Y    Y    Male
# 3    Y    Y  Female
# 4    Y    Y    Male

# %%
from sklearn.metrics import confusion_matrix

def compute_metrics(df):
    tn, fp, fn, tp = confusion_matrix(df["true"], df["pred"]).ravel()
    
    return {
        "TP": tp,
        "FP": fp,
        "TN": tn,
        "FN": fn,
        "Approval Rate": (tp + fp) / len(df),
        "False Positive Rate": fp / (fp + tn) if (fp + tn) != 0 else 0,
        "False Negative Rate": fn / (fn + tp) if (fn + tp) != 0 else 0
    }

# %%
male_metrics = compute_metrics(results[results["gender"] == "Male"])
female_metrics = compute_metrics(results[results["gender"] == "Female"])

# %%
fairness_df = pd.DataFrame([male_metrics, female_metrics], index=["Male", "Female"])
fairness_df
# Out:
#         TP  FP  TN  FN  Approval Rate  False Positive Rate  \
# Male    67  20  15   1       0.844660             0.571429
# Female  11   5   3   0       0.842105             0.625000
#
#         False Negative Rate
# Male               0.014706
# Female             0.000000

# %% [markdown]
# **Women are NOT being unfairly rejected (FNR = 0)**
#
# **Women are being wrongly approved more often (higher FPR)**
#
# **Approval difference is small**
#
# **Dataset is heavily imbalanced (67M vs 11F)**

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0   Male      No          0      Graduate            No             5849                0.0         NaN             360.0             1.0         Urban           Y
# 1   Male     Yes          1      Graduate            No             4583             1508.0       128.0             360.0             1.0         Rural           N
# 2   Male     Yes          0      Graduate           Yes             3000                0.0        66.0             360.0             1.0         Urban           Y
# 3   Male     Yes          0  Not Graduate            No             2583             2358.0       120.0             360.0             1.0         Urban           Y
# 4   Male      No          0      Graduate            No             6000                0.0       141.0             360.0             1.0         Urban           Y
